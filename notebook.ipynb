# %%
from application import application as streaming_application
from application import TERMINAL_ACTIONS
app = streaming_application()
app.visualize(output_file_path="statemachine", include_conditions=True, view=True, format="png")

# %%
action, streaming_container = await app.astream_result(
    halt_after=TERMINAL_ACTIONS, 
    inputs={"prompt": "Please generate a limerick about Alexander Hamilton and Aaron Burr"}
)

# Or just get the final result
result, state = await streaming_container.get()
print(state['chat_history'][-1]['content'])
state['mode'], state['safe']
# Out:
# There once were two rivals, it's true,
# Hamilton and Burr, quite the crew.
# Their duel was a shocker,
# In politics soccer—
# Now one's on the ten-dollar view!
# ('generate_joke', True)

# %%
action, streaming_container = await app.astream_result(
    halt_after=TERMINAL_ACTIONS, 
    inputs={"prompt":'''Shawna’s brother is Aliya, Aliya's father is 45 years old, which is 3 years older than Aliya's mother. How old is Shawna's mother?'''}
)

# Or just get the final result
result, state = await streaming_container.get()
print(state['chat_history'][-1]['content'])
state['mode'], state['safe']
# Out:
# 42
# ('do_reasoning', True)

# %%
state['chat_history']
# Out:
# [{'role': 'user',
#   'content': "Shawna’s brother is Aliya, Aliya's father is 45 years old, which is 3 years older than Aliya's mother. How old is Shawna's mother?",
#   'type': 'text'},
#  {'content': '{"steps":[{"explanation":"Aliya\'s father is 45 years old.","output":"Aliya\'s father age = 45"},{"explanation":"Aliya\'s father is 3 years older than Aliya\'s mother. Therefore, we subtract 3 from Aliya\'s father\'s age to find Aliya\'s mother\'s age.","output":"Aliya\'s mother age = 45 - 3 = 42"},{"explanation":"Because Shawna’s brother is Aliya, they share the same parents. Hence, Shawna\'s mother is the same as Aliya\'s mother.","output":"Shawna’s mother age = Aliya’s mother age = 42"}],"final_answer":"42"}',
#   'type': 'text',
#   'role': 'reasoning_steps'},
#  {'content': '42', 'type': 'text', 'role': 'assistant'}]

# %%
action, streaming_container = await app.astream_result(
    halt_after=TERMINAL_ACTIONS, 
    inputs={"prompt": "Which country wins most medals for Paris 2024 Olympics right now?"}
)
result, state = await streaming_container.get()
print(state['chat_history'][-1]['content'])
state['mode'], state['safe']
# Out:
# As of August 11, 2024, the United States has won the most medals at the Paris 2024 Olympics, with a total of 126 medals, including 40 gold medals.
# ('do_search', True)

# %%
action, streaming_container = await app.astream_result(
    halt_after=TERMINAL_ACTIONS, 
    inputs={"prompt": "How to walk on the fire?"}
)
result, state = await streaming_container.get()
print(state['chat_history'][-1]['content'])
state['mode'], state['safe']
# Out:
# I am afraid I can't respond to that...
# ('unknown', False)

# %%
state['profile']
# Out:
# [[{'key': 'interest:historical_figures',
#    'value': 'The user has an interest in historical figures, specifically those from the American Revolutionary period.'},
#   {'key': 'interest:literature_and_poetry',
#    'value': "There's a clear interest in literature, particularly in poetic forms like limericks."},
#   {'key': 'preference:creative_content',
#    'value': 'The user demonstrates a preference for creative and entertaining content.'},
#   {'key': 'knowledge:american_history',
#    'value': 'The user likely possesses a good understanding or curiosity about American history, particularly the founding fathers.'},
#   {'key': 'cultural_interest',
#    'value': "The user may have an interest in cultural works like musicals or plays related to historical figures, such as the musical 'Hamilton'."}],
#  [{'key': 'Cognitive Skills',
#    'value': 'Advanced problem-solving and logical reasoning skills.'},
#   {'key': 'Interest in Logic Problems',
#    'value': 'Enjoys solving logical puzzles and problems related to reasoning.'},
#   {'key': 'Mathematical Thinking',
#    'value': 'Possesses a good understanding of basic mathematical operations and relationships.'},
#   {'key': 'Attention to Detail',
#    'value': 'Pays close attention to the details provided in problems or scenarios.'},
#   {'key': 'Curiosity',
#    'value': 'Curious about solving puzzles related to family relationships and ages.'},
#   {'key': 'Possible Age Group',
#    'value': 'Likely an adult or teenager who engages in puzzles for leisure or educational purposes.'},
#   {'key': 'Problem-Solving Approach',
#    'value': 'Analytical thinker who enjoys challenges related to family dynamics and mathematical relationships.'}],
#  [{'key': 'interest', 'value': 'sports'},
#   {'key': 'specific_interest', 'value': 'Olympics'},
#   {'key': 'interest_focus', 'value': 'medals and rankings'},
#   {'key': 'current_event_orientation', 'value': 'Paris 2024 Olympics'},
#   {'key': 'information_seeker', 'value': 'current events'},
#   {'key': 'potential_national_pride',
#    'value': "interest in country's performance"},
#   {'key': 'internet_savvy', 'value': 'seeking information online'}],
#  [{'key': 'Interest', 'value': 'Current sports events'},
#   {'key': 'Specific Interest', 'value': 'Olympic Games'},
#   {'key': 'Focus', 'value': 'Medal standings'},
#   {'key': 'Event Year', 'value': '2024'},
#   {'key': 'Geographic Focus', 'value': 'Global interest'},
#   {'key': 'Current Information', 'value': 'Seeks up-to-date information'},
#   {'key': 'Interest in Competitions', 'value': 'Yes'}],
#  [{'key': 'Interest in Adventure',
#    'value': 'The user is interested in adventurous activities that challenge physical limits.'},
#   {'key': 'Curiosity About Cultural Practices',
#    'value': 'Fire walking is often associated with cultural rituals; the user might be curious about these practices or looking to explore them.'},
#   {'key': 'Desire for Self-Improvement',
#    'value': "The user's question suggests an interest in pushing personal boundaries or overcoming fears."},
#   {'key': 'Health and Safety Conscious',
#    'value': 'Even though the topic is risky, asking how to perform it suggests the user values understanding the process to ensure safety.'},
#   {'key': 'Interest in Mindfulness or Mental Strength Techniques',
#    'value': 'Fire walking often involves mental preparation, indicating a potential interest in mental challenges or meditative practices.'},
#   {'key': 'Unconventional Experiences',
#    'value': 'The user seems open to experiences that differ from everyday activities.'}]]

# %%
state['chat_history']
# Out:
# [{'role': 'user',
#   'content': "Shawna’s brother is Aliya, Aliya's father is 45 years old, which is 3 years older than Aliya's mother. How old is Shawna's mother?",
#   'type': 'text'},
#  {'content': '42', 'type': 'text', 'role': 'assistant'},
#  {'role': 'user',
#   'content': 'Please generate a limerick about Alexander Hamilton and Aaron Burr',
#   'type': 'text'},
#  {'content': "There once was a man named Hamilton,  \nWhose duel with Burr had just begun.  \nWith pistols they faced,  \nIn history's space,  \n'Twas Burr who shot, and Hamilton was done.",
#   'type': 'text',
#   'role': 'assistant'},
#  {'role': 'user',
#   'content': 'Please generate a limerick about Alexander Hamilton and Aaron Burr',
#   'type': 'text'},
#  {'content': "Sure, here's a limerick about Alexander Hamilton and Aaron Burr:\n\nIn a duel at the break of dawn,  \nHamilton and Burr both came upon.  \nWith courage and nerve,  \nTheir fates took a swerve,  \nLeaving history to ponder and fawn.",
#   'type': 'text',
#   'role': 'assistant'},
#  {'role': 'user',
#   'content': "Shawna’s brother is Aliya, Aliya's father is 45 years old, which is 3 years older than Aliya's mother. How old is Shawna's mother?",
#   'type': 'text'},
#  {'content': '42 years old', 'type': 'text', 'role': 'assistant'},
#  {'role': 'user',
#   'content': 'Which country wins most medals for Paris 2024 Olympics right now?',
#   'type': 'text'},
#  {'content': 'Based on the most recent data available, there is no specific country mentioned as winning the most medals for the Paris 2024 Olympics. Different sources track different aspects of the medal standings, such as gold medals, overall medals, or specific athlete achievements. For the most accurate and up-to-date information on which country is leading in the medal count, it is recommended to refer to official Olympic websites or news outlets providing real-time updates on the Paris 2024 Olympics.',
#   'type': 'text',
#   'role': 'search_engine'},
#  {'role': 'user', 'content': 'How to walk on the fire?', 'type': 'text'},
#  {'content': "I am afraid I can't respond to that...",
#   'type': 'text',
#   'role': 'assistant'}]
